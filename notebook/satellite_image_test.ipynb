# %% [markdown]
# Doc link : https://docs.google.com/document/d/1IfOsvd3IZOMQTNN4y9tCdvD8QRpSMbfUt1QxDKJRXLM/edit?usp=sharing

# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_path = "../../S2B_MSIL2A_20190612T044709_N0212_R076_T45RUL_20190612T085347.SAFE/GRANULE/L2A_T45RUL_A011828_20190612T045847/IMG_DATA/R10m/"

# %%
# !ls ~/snap/pycharm-community/common/S2B_MSIL2A_20190612T044709_N0212_R076_T45RUL_20190612T085347.SAFE/GRANULE/L2A_T45RUL_A011828_20190612T045847/IMG_DATA/R20m
# Out:
# T45RUL_20190612T044709_AOT_20m.jp2  T45RUL_20190612T044709_B11_20m.jp2
# T45RUL_20190612T044709_B02_20m.jp2  T45RUL_20190612T044709_B12_20m.jp2
# T45RUL_20190612T044709_B03_20m.jp2  T45RUL_20190612T044709_B8A_20m.jp2
# T45RUL_20190612T044709_B04_20m.jp2  T45RUL_20190612T044709_SCL_20m.jp2
# T45RUL_20190612T044709_B05_20m.jp2  T45RUL_20190612T044709_TCI_20m.jp2
# T45RUL_20190612T044709_B06_20m.jp2  T45RUL_20190612T044709_WVP_20m.jp2
# T45RUL_20190612T044709_B07_20m.jp2

# %% [markdown]
# https://sentinel.esa.int/documents/247904/685211/Sentinel-2+Products+Specification+Document+%28PSD%29/0f7bedeb-9fbb-4b60-91aa-809162de456c
#
# Combination of band for different Purpose
#
# Natural Colors: 4 3 2
# False color Infrared: 8 4 3
# False color Urban: 12 11 4
# Agriculture: 11 8 2
# Atmospheric penetration: 12 11 8a
# Healthy vegetation: 8 11 2
# Land/Water: 8 11 4
# Natural Colors with Atmospheric Removal: 12 8 3
# Shortwave Infrared: 12 8 4
# Vegetation Analysis: 11 8 4

# %% [markdown]
# ![alt text](im.png "Title")

# %%
band2 = rasterio.open(image_path + "T45RUL_20190612T044709_B02_10m.jp2", driver="JP2OpenJPEG") #blue
band3 = rasterio.open(image_path + "T45RUL_20190612T044709_B03_10m.jp2", driver="JP2OpenJPEG") #green
band4 = rasterio.open(image_path + "T45RUL_20190612T044709_B04_10m.jp2", driver="JP2OpenJPEG") #red
band8 = rasterio.open(image_path + "T45RUL_20190612T044709_B08_10m.jp2", driver="JP2OpenJPEG") #red

# %%
band2.count
# Out:
# 1

# %%
band2.shape , band8.shape , band2.block_shapes , band2.block_size, band2.dtypes
# Out:
# ((10980, 10980),
#  (10980, 10980),
#  [(1024, 1024)],
#  <function DatasetReader.block_size>,
#  ('uint16',))

# %% [markdown]
# #### 16 bits of data per pixel

# %%
plot.show(band2, cmap= "Blues"), plot.show(band3, cmap="Greens") , plot.show(band4, cmap = "Reds"), plot.show(band8)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f264bcf8438>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f267956ee10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f2678cecef0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f2679545ef0>)

# %%
trueColor = rasterio.open('SentinelTrueColor2.tiff','w',driver='Gtiff',
                         width=band4.width, height=band4.height,
                         count=3,
                         crs=band4.crs,
                         transform=band4.transform,
                         dtype=band4.dtypes[0]
                         )
trueColor.write(band2.read(1),3) #blue
trueColor.write(band3.read(1),2) #green
trueColor.write(band4.read(1),1) #red
trueColor.close()

# %%
src = rasterio.open(r"SentinelTrueColor2.tiff", count=3)
plot.show(src)

# %% [markdown]
# # EarthPy

# %% [markdown]
# https://www.earthdatascience.org/courses/earth-analytics-python/multispectral-remote-sensing-in-python/landsat-bands-geotif-in-Python/

# %%
# !pip3 install earthpy
import earthpy as et
import earthpy.spatial as es
# Out:
# Collecting earthpy
# Collecting geopandas (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/74/42/f4b147fc7920998a42046d0c2e65e61000bc5d104f1f8aec719612cb2fc8/geopandas-0.5.0-py2.py3-none-any.whl
# Collecting Rtree>=0.8 (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/33/0d/0bcb0fdd759570e85697189f675fa462131e5636482f2832288bbe4bb6f7/Rtree-0.8.3-py3-none-any.whl
# Collecting rasterio (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/a2/d6/f5dc5b31b5bbb8c9cf0ae2f38a31e4406994db48f9f14d9434588c935c7c/rasterio-1.0.24-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scikit-image (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/d4/ab/674e168bf7d0bc597218b3bec858d02c23fbac9ec1fec9cad878c6cee95f/scikit_image-0.15.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting matplotlib>=2.0.0 (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/da/83/d989ee20c78117c737ab40e0318ea221f1aed4e3f5a40b4f93541b369b93/matplotlib-3.1.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.14.0 (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl
# Collecting fiona (from geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/89/4a/193cd6a75e51062c85f4e1cd6f312b3bbda6e26ba7510f152ef5016f0b16/Fiona-1.8.6-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pyproj (from geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/ac/1a/81ef33d97354eb7d1765a921ecaf2ece41fd7927937b7c74124b6a2a0d99/pyproj-2.2.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting shapely (from geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pandas (from geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/19/74/e50234bc82c553fecdbd566d8650801e3fe2d6d8c8d940638e3d8a7c5522/pandas-0.24.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting setuptools (from Rtree>=0.8->earthpy)
#   Using cached https://files.pythonhosted.org/packages/ec/51/f45cea425fd5cb0b0380f5b0f048ebc1da5b417e48d304838c02d6288a1e/setuptools-41.0.1-py2.py3-none-any.whl
# Collecting click<8,>=4.0 (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl
# Collecting click-plugins (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting attrs (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
# Collecting cligj>=0.5 (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Collecting snuggs>=1.4.1 (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/58/14/8e90b7586ab6929861161e73e9fd55637a060e4d14dd1be14a4b8a08751f/snuggs-1.4.6-py3-none-any.whl
# Collecting affine (from rasterio->earthpy)
#   Using cached https://files.pythonhosted.org/packages/56/5d/6877929932d17850fa4903d0db8233ec8ed35aab7ceae96fa44ea6d479bd/affine-2.2.2-py2.py3-none-any.whl
# Collecting PyWavelets>=0.4.0 (from scikit-image->earthpy)
#   Using cached https://files.pythonhosted.org/packages/4e/cd/528dba0b474b08f6f9a3a5e1b4bb23d8e33ed5d9f0e321cc967c2607df05/PyWavelets-1.0.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scipy>=0.17.0 (from scikit-image->earthpy)
#   Using cached https://files.pythonhosted.org/packages/72/4c/5f81e7264b0a7a8bd570810f48cd346ba36faedbd2ba255c873ad556de76/scipy-1.3.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting networkx>=2.0 (from scikit-image->earthpy)
# Collecting pillow>=4.3.0 (from scikit-image->earthpy)
#   Using cached https://files.pythonhosted.org/packages/d2/c2/f84b1e57416755e967236468dcfb0fad7fd911f707185efc4ba8834a1a94/Pillow-6.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting imageio>=2.0.1 (from scikit-image->earthpy)
#   Using cached https://files.pythonhosted.org/packages/af/0a/943c965d372dae0b1f1482677d29030ab834351a61a9a632fd62f27f1523/imageio-2.5.0-py3-none-any.whl
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->earthpy)
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib>=2.0.0->earthpy)
#   Using cached https://files.pythonhosted.org/packages/dd/d9/3ec19e966301a6e25769976999bd7bbe552016f0d32b577dc9d63d2e0c49/pyparsing-2.4.0-py2.py3-none-any.whl
# Collecting python-dateutil>=2.1 (from matplotlib>=2.0.0->earthpy)
#   Using cached https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib>=2.0.0->earthpy)
#   Using cached https://files.pythonhosted.org/packages/f8/a1/5742b56282449b1c0968197f63eae486eca2c35dcd334bab75ad524e0de1/kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting munch (from fiona->geopandas->earthpy)
# Collecting six>=1.7 (from fiona->geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting pytz>=2011k (from pandas->geopandas->earthpy)
#   Using cached https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl
# Collecting decorator>=4.3.0 (from networkx>=2.0->scikit-image->earthpy)
#   Using cached https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
# Installing collected packages: six, munch, click, cligj, click-plugins, attrs, fiona, pyproj, shapely, python-dateutil, numpy, pytz, pandas, geopandas, setuptools, Rtree, pyparsing, snuggs, affine, rasterio, PyWavelets, scipy, cycler, kiwisolver, matplotlib, decorator, networkx, pillow, imageio, scikit-image, earthpy
# Successfully installed PyWavelets-1.0.3 Rtree-0.8.3 affine-2.2.2 attrs-19.1.0 click-7.0 click-plugins-1.1.1 cligj-0.5.0 cycler-0.10.0 decorator-4.4.0 earthpy-0.6.9 fiona-1.8.6 geopandas-0.5.0 imageio-2.5.0 kiwisolver-1.1.0 matplotlib-3.1.0 munch-2.3.2 networkx-2.3 numpy-1.16.4 pandas-0.24.2 pillow-6.0.0 pyparsing-2.4.0 pyproj-2.2.0 python-dateutil-2.8.0 pytz-2019.1 rasterio-1.0.24 scikit-image-0.15.0 scipy-1.3.0 setuptools-41.0.1 shapely-1.6.4.post2 six-1.12.0 snuggs-1.4.6
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-32b0c0bf9d90> in <module>
#       1 get_ipython().system('pip3 install earthpy')
#       2 import earthpy as et
# ----> 3 import earthpy.spatial as es
#
# ~/.local/lib/python3.6/site-packages/earthpy/spatial.py in <module>
#      13 import numpy as np
#      14 from shapely.geometry import mapping, box
# ---> 15 import geopandas as gpd
#      16 import rasterio as rio
#      17 from rasterio.mask import mask
#
# ~/.local/lib/python3.6/site-packages/geopandas/__init__.py in <module>
# ----> 1 from geopandas.geoseries import GeoSeries
#       2 from geopandas.geodataframe import GeoDataFrame
#       3 from geopandas.geodataframe import points_from_xy
#       4
#       5 from geopandas.io.file import read_file
#
# ~/.local/lib/python3.6/site-packages/geopandas/geoseries.py in <module>
#      11
#      12 from geopandas.plotting import plot_series
# ---> 13 from geopandas.base import GeoPandasBase, _unary_op, _CoordinateIndexer
#      14
#      15
#
# ~/.local/lib/python3.6/site-packages/geopandas/base.py in <module>
#      15
#      16 try:
# ---> 17     from rtree.core import RTreeError
#      18     HAS_SINDEX = True
#      19 except ImportError:
#
# ~/.local/lib/python3.6/site-packages/rtree/__init__.py in <module>
# ----> 1 from .index import Rtree
#       2
#       3 from .core import rt
#       4
#       5 __version__ = '0.8.3'
#
# ~/.local/lib/python3.6/site-packages/rtree/index.py in <module>
#       3 import pprint
#       4
# ----> 5 from . import core
#       6 import ctypes
#       7 try:
#
# ~/.local/lib/python3.6/site-packages/rtree/core.py in <module>
#     123
#     124     if lib_name is None:
# --> 125         raise OSError("Could not find libspatialindex_c library file")
#     126
#     127     rt = ctypes.CDLL(lib_name)
#
# OSError: Could not find libspatialindex_c library file

# %% [raw]
# # The error and its solution.
#
# sudo apt-get install automake
# sudo apt-get install libtool
# sudo apt-get install pkg-config
#
# curl -L https://github.com/libspatialindex/libspatialindex/archive/1.8.5.tar.gz | tar xz
# cd libspatialindex-1.8.5/
# ./autogen.sh
# ./configure
# make
# sudo make install
# sudo ldconfig

# %%
import earthpy as et
import earthpy.spatial as e

# %%
import earthpy.plot as ep

# %%
ep.plot_bands(band2.read(), cbar=False)
ep.plot_bands(band3.read(), cbar=False)
ep.plot_bands(band4.read(), cbar=False)
ep.plot_bands(band8.read(), cbar=False)
plt.show()

# %% [markdown]
# #### At a simple level, NDVI correlates with chlorophyll, which in turn correlates with plant health. Most space-based and terrestrial platforms that are used for agriculture, forestry, and similar applications have visual Red and NIR detector hardware, so NDVI has become a well-known, widely-used product. https://sentera.com/ndvi-vs-ndre-whats-difference/

# %%
NDVI = e.normalized_diff(band4.read(), band8.read())
ep.plot_bands(NDVI, cmap="RdYlGn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-23-d66eb8026121> in <module>
# ----> 1 NDVI = e.normalized_diff(band4.read(), band8.read())
#       2 ep.plot_bands(NDVI, cmap="RdYlGn")
#       3 plt.show()
#
# ~/.local/lib/python3.6/site-packages/earthpy/spatial.py in normalized_diff(b1, b2)
#     102     # Ignore warning for division by zero
#     103     with np.errstate(divide="ignore"):
# --> 104         n_diff = (b1 - b2) / (b1 + b2)
#     105
#     106     # Set inf values to nan and provide custom warning
#
# MemoryError:
